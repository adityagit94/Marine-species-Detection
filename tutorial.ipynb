# %% [markdown]
# # 🌊 Marine Species Detection Tutorial
#
# Welcome to the Marine Detect tutorial! This notebook will guide you through using the marine species detection models step by step.
#
# ## 📋 Learning Objectives
# By the end of this tutorial, you will:
# 1. Understand how to load and use YOLO models
# 2. Process images and videos for marine species detection
# 3. Analyze and interpret model results
# 4. Experiment with different parameters
#
# ## 🔧 Prerequisites
# - Basic Python knowledge
# - Familiarity with image processing concepts
# - Understanding of machine learning basics

# %% [markdown]
# ## 1. Setup and Imports
#
# First, let's import all necessary libraries and set up our environment.

# %%
# Standard library imports
import os
import sys
from pathlib import Path

# Third-party imports
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from ultralytics import YOLO
import pandas as pd

# Add src to path for imports
sys.path.append('src')
from marine_detect.predict import predict_on_images, predict_on_video

# Set up matplotlib for better plots
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 8)

print("✅ All libraries imported successfully!")
